# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/raveendra sawkar/Documents/IITH Docs/ML EtE Hackathon/NYC Parking Ticket Problem/archive/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv")

# %%
df.head(5)
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1283294138  GBB9093                 NY        PAS  08/04/2013
# 1      1283294151  62416MB                 NY        COM  08/04/2013
# 2      1283294163  78755JZ                 NY        COM  08/05/2013
# 3      1283294175  63009MA                 NY        COM  08/05/2013
# 4      1283294187  91648MC                 NY        COM  08/08/2013
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              46              SUBN         AUDI              P         37250
# 1              46               VAN         FORD              P         37290
# 2              46               P-U        CHEVR              P         37030
# 3              46               VAN         FORD              P         37270
# 4              41              TRLR          GMC              P         37240
#
#    ...  Hydrant Violation  Double Parking Violation  Latitude  Longitude  \
# ...

# %%
df = pd.concat([df.head(5000), df.tail(5000)])

# %%
df
# Out:
#           Summons Number Plate ID Registration State Plate Type Issue Date  \
# 0                    NaN      NaN                NaN        NaN        NaN
# 1                    NaN      NaN                NaN        NaN        NaN
# 2                    NaN      NaN                NaN        NaN        NaN
# 3                    NaN      NaN                NaN        NaN        NaN
# 4                    NaN      NaN                NaN        NaN        NaN
# ...                  ...      ...                ...        ...        ...
# 24999995             NaN      NaN                NaN        NaN        NaN
# 24999996             NaN      NaN                NaN        NaN        NaN
# 24999997             NaN      NaN                NaN        NaN        NaN
# 24999998             NaN      NaN                NaN        NaN        NaN
# 24999999             NaN      NaN                NaN        NaN        NaN
#
# ...
